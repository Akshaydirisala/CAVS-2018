# %%
import numpy as np
import pandas as pd
import matplotlib as mlib

# %%
CAVS_data=pd.read_csv("CAVS_DATA.csv")

# %%
CAVS_data.tail(n=10)
# Out:
#     JERSEY_NUMBER             PLAYER  GAME DATE  OPPONENT  HOMEGAME  \
# 9              16         Cedi_Osman        NaN       NaN       NaN
# 10             20         Kay_Felder        NaN       NaN       NaN
# 11             21   Kendrick_Perkins        NaN       NaN       NaN
# 12             23       Lebron_James        NaN       NaN       NaN
# 13             24  Richard_Jefferson        NaN       NaN       NaN
# 14             26        Kyle_Korver        NaN       NaN       NaN
# 15             32         Jeff_Green        NaN       NaN       NaN
# 16             41         Ante_Zizic        NaN       NaN       NaN
# 17             81      Jose_Calderon        NaN       NaN       NaN
# 18             99        Jae_Crowder        NaN       NaN       NaN
#
#     PLAYER_POSITION  MIN  PTS  FGM  FGA     ...       OFREB  DFREB  REB  AST  \
# 9               NaN  NaN  NaN  NaN  NaN     ...         NaN    NaN  NaN  NaN
# ...
